# %%
# Dependencies
import tweepy
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# Twitter API Keys
consumer_key = "rCbWtovJAFghaFtaYRC4onoR6"
consumer_secret = "zGp8VHdUY7Tj2Nrt3p96TMjSc60j1lTdXTGs7D97OVjp7iTb7h"
access_token = "21012720-SIwApJq2gKjaizZGWaQeZBSlymXVs7oBQku33q87v"
access_token_secret = "vqBXMQSdG5cQyNWOA0dSO0GXc9YShX86wKK3yUdSLlZcj"

# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
user_list = ["CNN", "FoxNews", "nytimes", "BBCWorld", "CBS" ]

# Variables for holding sentiments
tweet_data = {
    "tweet_source":[],
    "tweet_text":[],
    "tweet_date":[],
    "compound_list":[],
    "positive_list":[],
    "negative_list":[],
    "neutral_list":[]}

positive_list=[]
negative_list=[]
neutral_list=[]

#for status in tweepy.Cursor(api.user_timeline).items(100):
#process_status(status)

# Loop through 10 pages of tweets (total 200 tweets)
for x in range(5):

    # Loop through each user
    for user in user_list:

    # Get all tweets from home feed
        tweets = api.user_timeline(user, page=x+1)

        # Loop through all tweets
        for tweet in tweets:
            #print(tweet['text'])

            tweet_data["tweet_source"].append(tweet["user"]["name"])
            tweet_data["tweet_text"].append(tweet["text"])
            tweet_data["tweet_date"].append(tweet["created_at"])

            # Run Vader Analysis on each tweet

            tweet_data["compound_list"].append(analyzer.polarity_scores(tweet["text"])["compound"])

            #compound = analyzer.polarity_scores(tweet["text"])["compound"]
            pos = analyzer.polarity_scores(tweet["text"])["pos"]
            neu = analyzer.polarity_scores(tweet["text"])["neu"]
            neg = analyzer.polarity_scores(tweet["text"])["neg"]

            # Add each value to the appropriate list
            #compound_list.append(compound)
            positive_list.append(pos)
            negative_list.append(neg)
            neutral_list.append(neu)

tweet_data["positive_list"]  = positive_list
tweet_data["negative_list"]  = negative_list
tweet_data["neutral_list"]  = neutral_list

all_data=pd.DataFrame(tweet_data, columns=["tweet_source",
    "tweet_text",
    "tweet_date",
    "compound_list",
    "positive_list",
    "negative_list",
    "neutral_list"])

all_data
# Out:
#          tweet_source                                         tweet_text  \
# 0                 CNN  This photographer snaps cancer-stricken kids a...
# 1                 CNN  Barbie unveiled dolls based on real-life figur...
# 2                 CNN  Inspired by her travels, this artist paints st...
# 3                 CNN  "They could divorce. They could own property. ...
# 4                 CNN  "Dumpster fire" is in the Merriam-Webster dict...
# 5                 CNN  Thousands of dead starfish were found washed u...
# 6                 CNN  Cecil the lion "suffered incredible cruelty fo...
# 7                 CNN  2,000 years ago, people watched as animals mys...
# 8                 CNN  The kind of floods we've only seen during stor...
# 9                 CNN  Fake news travels at a markedly faster rate on...
# 10                CNN  These high-performance cars, which are priced ...
# 11                CNN  Bones found on a remote Pacific island almost ...
# ...

# %%
len(all_data["negative_list"])
# Out:
# 500

# %%
all_data["compound_list"]
# Out:
# 0      0.0000
# 1      0.0000
# 2      0.7003
# 3      0.0000
# 4     -0.4588
# 5     -0.6486
# 6     -0.8934
# 7     -0.5574
# 8      0.0000
# 9     -0.4767
# 10    -0.0762
# 11     0.0000
# 12    -0.5423
# 13     0.2187
# 14     0.4754
# 15     0.4215
# 16     0.7096
# 17    -0.3400
# 18     0.1779
# 19     0.5574
# 20    -0.3863
# 21     0.4019
# 22    -0.6124
# 23     0.5719
# 24     0.0000
# 25     0.0000
# 26     0.3612
# 27    -0.0258
# 28     0.0000
# 29     0.0000
#         ...
# 470    0.3612
# 471    0.0000
# 472    0.0000
# 473    0.0000
# 474    0.0000
# 475    0.0000
# 476    0.0000
# 477   -0.2500
# 478    0.0000
# 479    0.1406
# 480    0.6588
# 481   -0.5106
# 482    0.0000
# 483    0.7525
# 484    0.0000
# 485    0.8516
# 486    0.8442
# 487    0.9230
# 488    0.5994
# 489    0.8834
# 490    0.8553
# 491    0.8553
# 492    0.9215
# 493    0.0000
# 494    0.5994
# 495    0.6908
# 496    0.0000
# 497   -0.2960
# 498    0.0000
# 499    0.3818
# ...

# %%
x_limit = len(tweet_data["negative_list"])

# List of values from 0 to 100 each value being 1 greater than the last
x_axis = len(all_data["negative_list"])
y_axis = all_data["compound_list"]

# Create a random array of data that we will use for our y values
plt.scatter(x_axis, y_axis, marker="o", facecolors="red", edgecolors="black",
            s=x_axis[::-1], alpha=0.75)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-949017f41625> in <module>()
#       7 # Create a random array of data that we will use for our y values
#       8 plt.scatter(x_axis, y_axis, marker="o", facecolors="red", edgecolors="black",
# ----> 9             s=x_axis[::-1], alpha=0.75)
#      10
#
# TypeError: 'int' object is not subscriptable

# %%
plt.bar(range(len(delayed_trains_pd.index)), delayed_trains_pd.values)
#plt.scatter(compound_list, index.tweet)
#plt.plot(range(len(time_in_between)), time_in_between, marker="o", 
               linewidth=0.0, alpha=0.8, color="r")
plt.xlim([0, len(public_tweets.index])

plt.xlabel("Compound Score")
plt.ylabel("Tweets Ago")
plt.title("Tweet Counts vs Follower Counts")
plt.show()

# %%
plt.bar(range(len(delayed_trains_pd.index)), delayed_trains_pd.values)
plt.xticks(range(len(delayed_trains_pd.index)), delayed_trains_pd.index, rotation=45)
plt.ylabel("Tweet Polarity")
plt.xlabel("Train Name")
plt.title("Overall media Sentiment Based on Twitter")
plt.show()
